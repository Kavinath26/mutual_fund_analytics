# %% [markdown]
# # Comprehensive Mutual Fund Exploratory Data Analysis (EDA) Report
#
# ### Executive Core Insights Matrix (Task 10 Execution Log)
#
# * **Insight 1 (NAV Lifecycles):** Daily tracking profiles display strong market cyclicality across all 40 asset options, capturing clear historical phases such as the 2022 post-pandemic volatility dip, the extended 2023 retail bull rally acceleration wave, and major institutional corrections during mid-2024.
#   * *Supporting Graphic:* `charts/01_nav_trends.png`
#
# * **Insight 2 (AUM Scale Hegemony):** Compound asset volume growth trends establish SBI Mutual Fund as the dominant industry leader, capturing an unparalleled milestone peak scaling up to ₹12.5 Lakh Crores by the close of the 2025 fiscal loop.
#   * *Supporting Graphic:* `charts/02_aum_growth_amc.png`
#
# * **Insight 3 (SIP Capital Velocity):** Monthly systematic allocation timelines show consistent, linear retail capital scaling, hitting a historic all-time high inflow transaction metric of ₹31,002 Crores in December 2025.
#   * *Supporting Graphic:* `charts/03_sip_inflow_trend.png`
#
# * **Insight 4 (Asset Seasonal Concentration):** Density heatmap models identify strong, persistent retail focus toward Equity products, showing heightened seasonal subscription inflows during the Q4 tax planning cycle (Jan-March).
#   * *Supporting Graphic:* `charts/04_category_heatmap.png`
#
# * **Insight 5 (Retail Demographic Anchor):** Age-profile distributions show that Millennials (ages 25-40) represent over 45% of active mutual fund investors, providing the primary foundation for current asset subscription volumes.
#   * *Supporting Graphic:* `charts/05a_demographics_pie.png`
#
# * **Insight 6 (Gender Capital Allocation):** Boxplot variations show that while individual transactional volumes for male investors have a higher baseline median value, female investment cohorts exhibit tighter statistical variance and fewer redemption outliers.
#   * *Supporting Graphic:* `charts/05b_demographics_boxplot.png`
#
# * **Insight 7 (Geographic Flow Disparities):** Regional cash influx concentrations confirm that T30 (Top 30 industrialized urban markets) control a dominant 70.4% share of capital investment volume, while B30 rural markets remain a long-tail growth channel.
#   * *Supporting Graphic:* `charts/06a_geo_state_bar.png` & `charts/06b_geo_tier_pie.png`
#
# * **Insight 8 (Account Portfolio Volume Scaling):** Cumulative retail ledger expansion models confirm total active mutual fund account folios nearly doubled, rising from an initial 13.26 Crore starting point in January 2022 to a peak of 26.12 Crore accounts by December 2025.
#   * *Supporting Graphic:* `charts/07_folio_growth.png`
#
# * **Insight 9 (Return Matrix Interdependence):** Daily percentage return cross-correlation maps show tight, near-unity performance dependencies (coefficients > 0.88) between funds belonging to identical asset classes, while showing clear structural diversification relative to debt portfolios.
#   * *Supporting Graphic:* `charts/08_returns_correlation.png`
#
# * **Insight 10 (Systemic Concentration Risks):** Sector allocation donut summaries highlight potential system concentration profile exposure, with the Financial Services and IT sectors swallowing up a combined 50.7% weighting across major equity portfolios.
#   * *Supporting Graphic:* `charts/09_sector_donut.png`
